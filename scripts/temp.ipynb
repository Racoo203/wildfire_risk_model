# %%
import logging
from pathlib import Path
from scripts.generate_report_figures import generate_all

logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")

# 2. Run with default parameters to process all seasons and categories
generate_all(
    categories=["factor_maps", "susceptibility_maps"]
)
# Out:
# INFO: Generating figures for seasons=['spring'], categories=['factor_maps']
# INFO: [spring] Rendered 14 factor map(s).
# INFO: Figure generation complete. See figures/manifest.json for the full index.
