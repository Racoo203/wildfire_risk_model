# %%
from src.pipeline.preprocessor import WildfirePreprocessor
import pandas as pd

# %%
wf_processor = WildfirePreprocessor('./config/config.yaml')
# Out:
# INFO: Logger initialized: wildfire_susceptibility

# %%
wf_processor.run_full_pipeline()
# Out:
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\vegetation.py:124: RuntimeWarning: Mean of empty slice
#   mean_ndvi = np.nanmean(np.stack(arrays, axis=0), axis=0).astype("float32")
# Rows remaining after month filter: 7339
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\vegetation.py:124: RuntimeWarning: Mean of empty slice
#   mean_ndvi = np.nanmean(np.stack(arrays, axis=0), axis=0).astype("float32")
# Rows remaining after month filter: 13872
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\climate.py:94: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.open_mfdataset(files, combine="by_coords")
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\vegetation.py:124: RuntimeWarning: Mean of empty slice
#   mean_ndvi = np.nanmean(np.stack(arrays, axis=0), axis=0).astype("float32")
# Rows remaining after month filter: 6583
# {'spring': WindowsPath('data/silver/model_datasets/dataset_clean_spring.csv'),
#  'summer': WindowsPath('data/silver/model_datasets/dataset_clean_summer.csv'),
#  'fall': WindowsPath('data/silver/model_datasets/dataset_clean_fall.csv')}
