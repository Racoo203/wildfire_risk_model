# %%
from src.pipeline.preprocessor import WildfirePreprocessor
import pandas as pd

# %%
wf_processor = WildfirePreprocessor('./config/config.yaml')
# Out:
# INFO: Logger initialized: wildfire_susceptibility

# %%
wf_processor.run_full_pipeline()
# Out:
# {'summer': WindowsPath('data/silver/model_datasets/dataset_clean_summer.csv')}

# %%
df = pd.read_csv("./data/silver/model_datasets/dataset_clean_summer.csv")

# %%
(df.isna().sum() / len(df)) * 100
# Out:
# elevation      0.000000
# slope          0.868835
# aspect         0.868835
# d_roads        0.000000
# d_rivers       0.000000
# d_activity     0.000000
# ndvi           0.028771
# tas            2.759810
# tasmax         2.759810
# tasmin         2.759810
# rainfall       2.759810
# sfcWind        2.759810
# hurs           2.759810
# label         78.943247
# dtype: float64
