# %%
from src.pipeline.preprocessor import WildfirePreprocessor

# %%
wf_processor = WildfirePreprocessor('./config/config.yaml')
# Out:
# INFO: Logger initialized: wildfire_risk_model

# %%
wf_processor.run_full_pipeline()
# Out:
# INFO: Starting wildfire preprocessing pipeline (seasonal)...
# INFO: Building static features...
# INFO: Merged 5 SRTM tiles → _tmp_srtm_merged.tif
# INFO: Slope and aspect derived from clipped DEM.
# INFO: Topography features complete.
# INFO: Roads: distance raster written -> dist_roads.tif
# INFO: Rivers: distance raster written -> dist_rivers.tif
# INFO: Human activity: distance raster written -> dist_activity.tif
# INFO: [spring] Climate feature ready: tas → meteo_tas_spring.tif
# INFO: [spring] Climate feature ready: tasmax → meteo_tasmax_spring.tif
# INFO: [spring] Climate feature ready: tasmin → meteo_tasmin_spring.tif
# INFO: [spring] Climate feature ready: rainfall → meteo_rainfall_spring.tif
# INFO: [spring] Climate feature ready: sfcWind → meteo_sfcWind_spring.tif
# INFO: [spring] Climate feature ready: hurs → meteo_hurs_spring.tif
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\vegetation.py:119: RuntimeWarning: Mean of empty slice
#   mean_ndvi = np.nanmean(np.stack(arrays, axis=0), axis=0).astype("float32")
# INFO: [spring] NDVI ready → ndvi_spring.tif
# INFO: Rows remaining after month filter: 7339
# INFO: [spring] d_fires built from 3570 training fires
# INFO: [spring][convolution] class counts: {0: 475235, 1: 118809, 2: 118809, 3: 79206} | zero-density (unlabelled) cells: 3059076 | out-of-domain NaN cells: 2606923
# INFO: [spring][convolution] diagnostic plot -> figures\density_dist_spring_convolution.png
# INFO: [summer] Climate feature ready: tas → meteo_tas_summer.tif
# INFO: [summer] Climate feature ready: tasmax → meteo_tasmax_summer.tif
# INFO: [summer] Climate feature ready: tasmin → meteo_tasmin_summer.tif
# INFO: [summer] Climate feature ready: rainfall → meteo_rainfall_summer.tif
# INFO: [summer] Climate feature ready: sfcWind → meteo_sfcWind_summer.tif
# INFO: [summer] Climate feature ready: hurs → meteo_hurs_summer.tif
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\vegetation.py:119: RuntimeWarning: Mean of empty slice
#   mean_ndvi = np.nanmean(np.stack(arrays, axis=0), axis=0).astype("float32")
# INFO: [summer] NDVI ready → ndvi_summer.tif
# INFO: Rows remaining after month filter: 13872
# INFO: [summer] d_fires built from 6286 training fires
# INFO: [summer][convolution] class counts: {0: 701683, 1: 175125, 2: 175716, 3: 116948} | zero-density (unlabelled) cells: 2681663 | out-of-domain NaN cells: 2606923
# INFO: [summer][convolution] diagnostic plot -> figures\density_dist_summer_convolution.png
# INFO: [fall] Climate feature ready: tas → meteo_tas_fall.tif
# INFO: [fall] Climate feature ready: tasmax → meteo_tasmax_fall.tif
# INFO: [fall] Climate feature ready: tasmin → meteo_tasmin_fall.tif
# INFO: [fall] Climate feature ready: rainfall → meteo_rainfall_fall.tif
# INFO: [fall] Climate feature ready: sfcWind → meteo_sfcWind_fall.tif
# INFO: [fall] Climate feature ready: hurs → meteo_hurs_fall.tif
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\features\vegetation.py:119: RuntimeWarning: Mean of empty slice
#   mean_ndvi = np.nanmean(np.stack(arrays, axis=0), axis=0).astype("float32")
# INFO: [fall] NDVI ready → ndvi_fall.tif
# INFO: Rows remaining after month filter: 6583
# INFO: [fall] d_fires built from 3422 training fires
# INFO: [fall][convolution] class counts: {0: 487899, 1: 123261, 2: 120221, 3: 83527} | zero-density (unlabelled) cells: 3036227 | out-of-domain NaN cells: 2606923
# INFO: [fall][convolution] diagnostic plot -> figures\density_dist_fall_convolution.png
# INFO: Pipeline complete for all active seasons.
# {'spring': WindowsPath('data/silver/model_datasets/dataset_clean_spring.csv'),
#  'summer': WindowsPath('data/silver/model_datasets/dataset_clean_summer.csv'),
#  'fall': WindowsPath('data/silver/model_datasets/dataset_clean_fall.csv')}
