# %%
from wildfire_susceptibility.pipeline.dataset_builder import DatasetBuilder

# %%
data_builder = DatasetBuilder('./wildfire_susceptibility/config/_working.yaml')
# Out:
# INFO: Logger initialized: wildfire_susceptibility

# %%
data_builder.run_full_pipeline()
# Out:
# INFO: Starting wildfire dataset-integration pipeline (seasonal)...
# INFO: Building static features via FEATURE_BUILDERS registry...
# INFO: Merged 5 SRTM tiles → _tmp_srtm_merged.tif
# INFO: Reprojected data\silver\layers\_tmp_srtm_merged.tif to data\silver\layers\_tmp_elev.tif
# INFO: Written data\silver\layers\_tmp_slope.tif
# INFO: Written data\silver\layers\_tmp_aspect.tif
# INFO: Slope and aspect derived from clipped DEM.
# INFO: Clipped data\silver\layers\_tmp_elev.tif to data\silver\layers\topo_elevation.tif
# INFO: Clipped data\silver\layers\_tmp_aspect.tif to data\silver\layers\topo_aspect.tif
# INFO: Clipped data\silver\layers\_tmp_slope.tif to data\silver\layers\topo_slope.tif
# INFO: Topography features complete.
# INFO: Distance raster -> dist_roads.tif (681,912 feature px)
# INFO: Roads: distance raster written -> dist_roads.tif
# INFO: Distance raster -> dist_rivers.tif (111,049 feature px)
# INFO: Rivers: distance raster written -> dist_rivers.tif
# ...
