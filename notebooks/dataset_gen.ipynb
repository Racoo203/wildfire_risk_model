# %%
from src.pipeline.preprocessor import WildfirePreprocessor

# %%
wf_processor = WildfirePreprocessor('./config/config.yaml')
# Out:
# INFO: Logger initialized: wildfire_risk_model

# %%
wf_processor.run_full_pipeline()
# Out:
# INFO: Starting wildfire preprocessing pipeline (seasonal)...
# INFO: Building static features...
# INFO: [spring][convolution][percentile] class counts: {0: 475235, 1: 118809, 2: 118809, 3: 79206} | zero-density (unlabelled) cells: 3059076 | out-of-domain NaN cells: 2606923 | breakpoints: [0.0012, 0.0045, 0.014]
# INFO: [spring][convolution][percentile] diagnostic plot -> figures\density_dist_spring_convolution_percentile.png
# INFO: [spring][convolution][jenks] class counts: {0: 642371, 1: 122295, 2: 25148, 3: 2245} | zero-density (unlabelled) cells: 3059076 | out-of-domain NaN cells: 2606923 | breakpoints: [0.0074, 0.0252, 0.068]
# INFO: [spring][convolution][jenks] diagnostic plot -> figures\density_dist_spring_convolution_jenks.png
# INFO: [spring][convolution][gmm] class counts: {0: 570555, 1: 183015, 2: 34523, 3: 3966} | zero-density (unlabelled) cells: 3059076 | out-of-domain NaN cells: 2606923 | breakpoints: [0.004000000189989805, 0.02070000022649765, 0.05649999901652336]
# INFO: [spring][convolution][gmm] diagnostic plot -> figures\density_dist_spring_convolution_gmm.png
# INFO: [summer][convolution][percentile] class counts: {0: 701683, 1: 175125, 2: 175716, 3: 116948} | zero-density (unlabelled) cells: 2681663 | out-of-domain NaN cells: 2606923 | breakpoints: [0.0015, 0.0058, 0.0158]
# INFO: [summer][convolution][percentile] diagnostic plot -> figures\density_dist_summer_convolution_percentile.png
# INFO: [summer][convolution][jenks] class counts: {0: 955516, 1: 179306, 2: 31637, 3: 3013} | zero-density (unlabelled) cells: 2681663 | out-of-domain NaN cells: 2606923 | breakpoints: [0.0089, 0.0328, 0.0967]
# INFO: [summer][convolution][jenks] diagnostic plot -> figures\density_dist_summer_convolution_jenks.png
# INFO: [summer][convolution][gmm] class counts: {0: 822875, 1: 276999, 2: 60842, 3: 8756} | zero-density (unlabelled) cells: 2681663 | out-of-domain NaN cells: 2606923 | breakpoints: [0.004000000189989805, 0.0215000007301569, 0.06289999932050705]
# INFO: [summer][convolution][gmm] diagnostic plot -> figures\density_dist_summer_convolution_gmm.png
# INFO: [fall][convolution][percentile] class counts: {0: 487899, 1: 123261, 2: 120221, 3: 83527} | zero-density (unlabelled) cells: 3036227 | out-of-domain NaN cells: 2606923 | breakpoints: [0.0011, 0.0043, 0.0134]
# INFO: [fall][convolution][percentile] diagnostic plot -> figures\density_dist_fall_convolution_percentile.png
# INFO: [fall][convolution][jenks] class counts: {0: 676593, 1: 120668, 2: 16588, 3: 1059} | zero-density (unlabelled) cells: 3036227 | out-of-domain NaN cells: 2606923 | breakpoints: [0.0078, 0.0294, 0.1025]
# INFO: [fall][convolution][jenks] diagnostic plot -> figures\density_dist_fall_convolution_jenks.png
# INFO: [fall][convolution][gmm] class counts: {0: 601032, 1: 180551, 2: 29738, 3: 3587} | zero-density (unlabelled) cells: 3036227 | out-of-domain NaN cells: 2606923 | breakpoints: [0.0038999998942017555, 0.02070000022649765, 0.05860000103712082]
# INFO: [fall][convolution][gmm] diagnostic plot -> figures\density_dist_fall_convolution_gmm.png
# INFO: Pipeline complete for all active seasons.
# {'spring': WindowsPath('data/silver/model_datasets/dataset_clean_spring.csv'),
#  'summer': WindowsPath('data/silver/model_datasets/dataset_clean_summer.csv'),
#  'fall': WindowsPath('data/silver/model_datasets/dataset_clean_fall.csv')}
