# %%
from src.wildfire_susceptibility.pipeline.dataset_builder import DatasetBuilder
from src.wildfire_susceptibility.config.loader import ConfigLoader

# %%
# config = ConfigLoader.load(
#     # config_dir="./src/wildfire_susceptibility/config",
#     files=["_working.yaml"],
# ).model_dump(mode="python")

config = ConfigLoader.load_experiment(
    name="summer_jenks_baseline"
).model_dump(mode="python")

data_builder = DatasetBuilder(config)
# Out:
# INFO: Logger initialized: wildfire_susceptibility

# %%
data_builder.run_full_pipeline()
# Out:
# INFO: Starting wildfire dataset-integration pipeline (seasonal)...
# INFO: Building static features via FEATURE_BUILDERS registry...
# INFO: Merged 5 SRTM tiles → _tmp_srtm_merged.tif
# INFO: Slope and aspect derived from clipped DEM.
# INFO: Topography features complete.
# INFO: Roads: distance raster written -> dist_roads.tif
# INFO: Rivers: distance raster written -> dist_rivers.tif
# INFO: Buildings: distance raster written -> dist_buildings.tif
# INFO: Land-use class raster written -> landuse_class.tif (11,555 polygons, 10 classes)
# c:\Users\rcorr\Documents\Development\wildfire_risk_model\src\wildfire_susceptibility\features\vegetation.py:107: RuntimeWarning: Mean of empty slice
#   mean_ndvi = np.nanmean(np.stack(arrays, axis=0), axis=0).astype("float32")
# INFO: [None][static] NDVI ready -> ndvi_static.tif
# INFO: Rows remaining after month filter: 13872
# INFO: [summer] d_fires built from 7172 training fires
# ...
