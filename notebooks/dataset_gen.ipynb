# %%
from wildfire_susceptibility.pipeline.preprocessor import WildfirePreprocessor

# %%
wf_processor = WildfirePreprocessor('./wildfire_susceptibility/config/defaults.yaml')
# Out:
# INFO: Logger initialized: wildfire_susceptibility

# %%
wf_processor.run_full_pipeline()
# Out:
# INFO: Starting wildfire preprocessing pipeline (seasonal)...
# INFO: Building static features via FEATURE_BUILDERS registry...
# INFO: [CACHED] BoundaryBuilder: outputs already exist, skipping computation
# INFO:   [cached] boundary -> data\silver\layers\boundary.shp
# INFO: [CACHED] TopographyBuilder: outputs already exist, skipping computation
# INFO:   [cached] elevation -> data\silver\layers\topo_elevation.tif
# INFO:   [cached] slope -> data\silver\layers\topo_slope.tif
# INFO:   [cached] aspect -> data\silver\layers\topo_aspect.tif
# INFO: [CACHED] ProximityBuilder: outputs already exist, skipping computation
# INFO:   [cached] d_roads -> data\silver\layers\dist_roads.tif
# INFO:   [cached] d_rivers -> data\silver\layers\dist_rivers.tif
# INFO:   [cached] d_activity -> data\silver\layers\dist_activity.tif
# INFO: [CACHED] ClimateBuilder[spring]: outputs already exist, skipping computation
# INFO:   [cached] tas -> data\silver\layers\meteo_tas_spring.tif
# INFO:   [cached] tasmax -> data\silver\layers\meteo_tasmax_spring.tif
# INFO:   [cached] tasmin -> data\silver\layers\meteo_tasmin_spring.tif
# INFO:   [cached] rainfall -> data\silver\layers\meteo_rainfall_spring.tif
# INFO:   [cached] sfcWind -> data\silver\layers\meteo_sfcWind_spring.tif
# INFO:   [cached] hurs -> data\silver\layers\meteo_hurs_spring.tif
# INFO: [CACHED] VegetationBuilder[spring]: outputs already exist, skipping computation
# INFO:   [cached] ndvi -> data\silver\layers\ndvi_spring.tif
# INFO: [CACHED] FireBuilder[spring]: outputs already exist, skipping computation
# INFO:   [cached] train -> data\silver\layers\fire_points_train_spring.gpkg
# INFO:   [cached] val -> data\silver\layers\fire_points_val_spring.gpkg
# INFO:   [cached] test -> data\silver\layers\fire_points_test_spring.gpkg
# INFO: [CACHED] FireProximityBuilder[spring]: outputs already exist, skipping computation
# INFO:   [cached] d_fires -> data\silver\layers\dist_fires_spring.tif
# INFO: [CACHED] KDClassifier[conv][spring]: outputs already exist, skipping computation
# INFO:   [cached] density -> data\silver\layers\fire_density_conv_spring.tif
# INFO: [CACHED] KDClassifier[convolution][percentile][spring]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_percentile_spring.tif
# INFO: [CACHED] KDClassifier[convolution][jenks][spring]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_jenks_spring.tif
# INFO: [CACHED] KDClassifier[convolution][gmm][spring]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_gmm_spring.tif
# INFO: Zero-imputed 2,606,923 NaNs in 'slope' (flat SRTM cells)
# INFO: Zero-imputed 2,606,923 NaNs in 'aspect' (flat SRTM cells)
# INFO: Nearest-neighbor filled 2,608,773 NaNs in 'ndvi'
# WARNING: Unresolved NaNs remain in columns {'elevation': 2606923, 'd_roads': 2606923, 'd_rivers': 2606923, 'd_activity': 2606923, 'tas': 2645791, 'tasmax': 2645791, 'tasmin': 2645791, 'rainfall': 2645791, 'sfcWind': 2645791, 'hurs': 2645791, 'd_fires': 2606923} after applying the three documented rules. Note: this count spans the full rectangular grid, including area outside the study boundary — check against the valid label mask before treating this as an in-domain data quality issue.
# INFO: [spring] Excluding 7,259 otherwise-labelled pixels from cleaning/training due to unresolved feature NaNs (e.g. climate resampling edges) — see per-feature breakdown above.
# INFO: [spring] LabelCleaner: flagged 199,695 / 565,023 Low-class pixels (35.34%) as ambiguous.
# INFO: [spring] Sensitivity analysis: 7 variants, max variance vs. baseline = 45.7318% -> label_cleaning_sensitivity_spring.csv
# WARNING: [spring] Sensitivity variance (45.7318%) exceeds 1% — flagged set may be sensitive to k-means initialization.
# INFO: Stacked elevation: 3,851,135 valid pixels
# INFO: Stacked slope: 3,851,135 valid pixels
# INFO: Stacked aspect: 3,851,135 valid pixels
# INFO: Stacked d_roads: 3,851,135 valid pixels
# INFO: Stacked d_rivers: 3,851,135 valid pixels
# INFO: Stacked d_activity: 3,851,135 valid pixels
# INFO: Stacked tas: 3,851,135 valid pixels
# INFO: Stacked tasmax: 3,851,135 valid pixels
# INFO: Stacked tasmin: 3,851,135 valid pixels
# INFO: Stacked rainfall: 3,851,135 valid pixels
# INFO: Stacked sfcWind: 3,851,135 valid pixels
# INFO: Stacked hurs: 3,851,135 valid pixels
# INFO: Stacked ndvi: 3,851,135 valid pixels
# INFO: Stacked d_fires: 3,851,135 valid pixels
# INFO: Stacked label: 3,851,135 valid pixels
# INFO: Dataset saved to data\silver\model_datasets\dataset_clean_spring.csv
# INFO: [CACHED] ClimateBuilder[summer]: outputs already exist, skipping computation
# INFO:   [cached] tas -> data\silver\layers\meteo_tas_summer.tif
# INFO:   [cached] tasmax -> data\silver\layers\meteo_tasmax_summer.tif
# INFO:   [cached] tasmin -> data\silver\layers\meteo_tasmin_summer.tif
# INFO:   [cached] rainfall -> data\silver\layers\meteo_rainfall_summer.tif
# INFO:   [cached] sfcWind -> data\silver\layers\meteo_sfcWind_summer.tif
# INFO:   [cached] hurs -> data\silver\layers\meteo_hurs_summer.tif
# INFO: [CACHED] VegetationBuilder[summer]: outputs already exist, skipping computation
# INFO:   [cached] ndvi -> data\silver\layers\ndvi_summer.tif
# INFO: [CACHED] FireBuilder[summer]: outputs already exist, skipping computation
# INFO:   [cached] train -> data\silver\layers\fire_points_train_summer.gpkg
# INFO:   [cached] val -> data\silver\layers\fire_points_val_summer.gpkg
# INFO:   [cached] test -> data\silver\layers\fire_points_test_summer.gpkg
# INFO: [CACHED] FireProximityBuilder[summer]: outputs already exist, skipping computation
# INFO:   [cached] d_fires -> data\silver\layers\dist_fires_summer.tif
# INFO: [CACHED] KDClassifier[conv][summer]: outputs already exist, skipping computation
# INFO:   [cached] density -> data\silver\layers\fire_density_conv_summer.tif
# INFO: [CACHED] KDClassifier[convolution][percentile][summer]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_percentile_summer.tif
# INFO: [CACHED] KDClassifier[convolution][jenks][summer]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_jenks_summer.tif
# INFO: [CACHED] KDClassifier[convolution][gmm][summer]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_gmm_summer.tif
# INFO: Zero-imputed 2,606,923 NaNs in 'slope' (flat SRTM cells)
# INFO: Zero-imputed 2,606,923 NaNs in 'aspect' (flat SRTM cells)
# INFO: Nearest-neighbor filled 2,608,700 NaNs in 'ndvi'
# WARNING: Unresolved NaNs remain in columns {'elevation': 2606923, 'd_roads': 2606923, 'd_rivers': 2606923, 'd_activity': 2606923, 'tas': 2645791, 'tasmax': 2645791, 'tasmin': 2645791, 'rainfall': 2645791, 'sfcWind': 2645791, 'hurs': 2645791, 'd_fires': 2606923} after applying the three documented rules. Note: this count spans the full rectangular grid, including area outside the study boundary — check against the valid label mask before treating this as an in-domain data quality issue.
# INFO: [summer] Excluding 8,891 otherwise-labelled pixels from cleaning/training due to unresolved feature NaNs (e.g. climate resampling edges) — see per-feature breakdown above.
# INFO: [summer] LabelCleaner: flagged 200,000 / 816,416 Low-class pixels (24.50%) as ambiguous.
# INFO: [summer] Sensitivity analysis: 7 variants, max variance vs. baseline = 37.0619% -> label_cleaning_sensitivity_summer.csv
# WARNING: [summer] Sensitivity variance (37.0619%) exceeds 1% — flagged set may be sensitive to k-means initialization.
# INFO: Stacked elevation: 3,851,135 valid pixels
# INFO: Stacked slope: 3,851,135 valid pixels
# INFO: Stacked aspect: 3,851,135 valid pixels
# INFO: Stacked d_roads: 3,851,135 valid pixels
# INFO: Stacked d_rivers: 3,851,135 valid pixels
# INFO: Stacked d_activity: 3,851,135 valid pixels
# INFO: Stacked tas: 3,851,135 valid pixels
# INFO: Stacked tasmax: 3,851,135 valid pixels
# INFO: Stacked tasmin: 3,851,135 valid pixels
# INFO: Stacked rainfall: 3,851,135 valid pixels
# INFO: Stacked sfcWind: 3,851,135 valid pixels
# INFO: Stacked hurs: 3,851,135 valid pixels
# INFO: Stacked ndvi: 3,851,135 valid pixels
# INFO: Stacked d_fires: 3,851,135 valid pixels
# INFO: Stacked label: 3,851,135 valid pixels
# INFO: Dataset saved to data\silver\model_datasets\dataset_clean_summer.csv
# INFO: [CACHED] ClimateBuilder[fall]: outputs already exist, skipping computation
# INFO:   [cached] tas -> data\silver\layers\meteo_tas_fall.tif
# INFO:   [cached] tasmax -> data\silver\layers\meteo_tasmax_fall.tif
# INFO:   [cached] tasmin -> data\silver\layers\meteo_tasmin_fall.tif
# INFO:   [cached] rainfall -> data\silver\layers\meteo_rainfall_fall.tif
# INFO:   [cached] sfcWind -> data\silver\layers\meteo_sfcWind_fall.tif
# INFO:   [cached] hurs -> data\silver\layers\meteo_hurs_fall.tif
# INFO: [CACHED] VegetationBuilder[fall]: outputs already exist, skipping computation
# INFO:   [cached] ndvi -> data\silver\layers\ndvi_fall.tif
# INFO: [CACHED] FireBuilder[fall]: outputs already exist, skipping computation
# INFO:   [cached] train -> data\silver\layers\fire_points_train_fall.gpkg
# INFO:   [cached] val -> data\silver\layers\fire_points_val_fall.gpkg
# INFO:   [cached] test -> data\silver\layers\fire_points_test_fall.gpkg
# INFO: [CACHED] FireProximityBuilder[fall]: outputs already exist, skipping computation
# INFO:   [cached] d_fires -> data\silver\layers\dist_fires_fall.tif
# INFO: [CACHED] KDClassifier[conv][fall]: outputs already exist, skipping computation
# INFO:   [cached] density -> data\silver\layers\fire_density_conv_fall.tif
# INFO: [CACHED] KDClassifier[convolution][percentile][fall]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_percentile_fall.tif
# INFO: [CACHED] KDClassifier[convolution][jenks][fall]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_jenks_fall.tif
# INFO: [CACHED] KDClassifier[convolution][gmm][fall]: outputs already exist, skipping computation
# INFO:   [cached] risk_labels -> data\silver\layers\risk_labels_convolution_gmm_fall.tif
# INFO: Zero-imputed 2,606,923 NaNs in 'slope' (flat SRTM cells)
# INFO: Zero-imputed 2,606,923 NaNs in 'aspect' (flat SRTM cells)
# INFO: Nearest-neighbor filled 2,609,024 NaNs in 'ndvi'
# WARNING: Unresolved NaNs remain in columns {'elevation': 2606923, 'd_roads': 2606923, 'd_rivers': 2606923, 'd_activity': 2606923, 'tas': 2645791, 'tasmax': 2645791, 'tasmin': 2645791, 'rainfall': 2645791, 'sfcWind': 2645791, 'hurs': 2645791, 'd_fires': 2606923} after applying the three documented rules. Note: this count spans the full rectangular grid, including area outside the study boundary — check against the valid label mask before treating this as an in-domain data quality issue.
# INFO: [fall] Excluding 4,938 otherwise-labelled pixels from cleaning/training due to unresolved feature NaNs (e.g. climate resampling edges) — see per-feature breakdown above.
# INFO: [fall] LabelCleaner: flagged 200,000 / 597,035 Low-class pixels (33.50%) as ambiguous.
# INFO: [fall] Sensitivity analysis: 7 variants, max variance vs. baseline = 44.6094% -> label_cleaning_sensitivity_fall.csv
# WARNING: [fall] Sensitivity variance (44.6094%) exceeds 1% — flagged set may be sensitive to k-means initialization.
# INFO: Stacked elevation: 3,851,135 valid pixels
# INFO: Stacked slope: 3,851,135 valid pixels
# INFO: Stacked aspect: 3,851,135 valid pixels
# INFO: Stacked d_roads: 3,851,135 valid pixels
# INFO: Stacked d_rivers: 3,851,135 valid pixels
# INFO: Stacked d_activity: 3,851,135 valid pixels
# INFO: Stacked tas: 3,851,135 valid pixels
# INFO: Stacked tasmax: 3,851,135 valid pixels
# INFO: Stacked tasmin: 3,851,135 valid pixels
# INFO: Stacked rainfall: 3,851,135 valid pixels
# INFO: Stacked sfcWind: 3,851,135 valid pixels
# INFO: Stacked hurs: 3,851,135 valid pixels
# INFO: Stacked ndvi: 3,851,135 valid pixels
# INFO: Stacked d_fires: 3,851,135 valid pixels
# INFO: Stacked label: 3,851,135 valid pixels
# INFO: Dataset saved to data\silver\model_datasets\dataset_clean_fall.csv
# INFO: Pipeline complete for all active seasons.
# {'spring': WindowsPath('data/silver/model_datasets/dataset_clean_spring.csv'),
#  'summer': WindowsPath('data/silver/model_datasets/dataset_clean_summer.csv'),
#  'fall': WindowsPath('data/silver/model_datasets/dataset_clean_fall.csv')}
